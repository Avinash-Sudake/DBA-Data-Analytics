# %%
# Python Day - 1

# %%
# Print Name With Emoji
print("Avi \U0001F600")
# Out:
# Avi 😀

# %%
# The Area Of Circle
r =5;
Area = 3.14*r*r;
print("The Area Of Circle Is =",Area);

# %%
# Addition Of Two Num
A=15
B=15
print("The Addition of",A,"+",B,"=",A+B)

# %%
# The Area of Circle Gives The User Input
r= int(input("Enter a value = "))
area = 3.14*r*r
print("The Area of Circle is",area)
# Out:
# Enter a value = 6
# The Area of Circle is 113.03999999999999
