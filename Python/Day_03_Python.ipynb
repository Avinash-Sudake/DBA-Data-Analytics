# %%
# Python Day - 3

# %%
# String Methods

a = "Hello"

print(a.upper())
print(a.lower())
print(a.startswith("h"))
print(a.find("o"))
print(a.index("H"))
print(a.replace("H","h"))
print("_______________________")
print(a[:])
print(a[::])
print(a[::])
print(a[::-1])
# Out:
# HELLO
# hello
# False
# 4
# 0
# hello
# _______________________
# Hello
# Hello
# Hello
# olleH

# %%
# split
f = "Today is Day 4 Of DBA_AI Course"
print(f.split("_"))
# Out:
# ['Today is Day 4 Of DBA', 'AI Course']

# %%
# JOin
g = "Hello"
print(" ".join(g))
# Out:
# H e l l o

# %%
from os import truncate
# Type Casting

# int()

a=int("67")
a=int(True)
a=int(False)
#print(45.23)
print(a)
print(type(a))
# Out:
# 0
# <class 'int'>

# %%
# Float
t = float(78)
t = float(True)
t = float(False)
# t = float("True") could not convert string to float: 'True'
t = float("67")
print(t)
print(type(t))
# Out:
# 67.0
# <class 'float'>

# %%
# String

h= str(6)
h= str(True)
h= str(False)
h= str(45.23)
print(h)
print(type(h))
# Out:
# 45.23
# <class 'str'>

# %%
# Bool
v = bool(7)
v = bool(-7)
v = bool(0)
v = bool(0.0)
v = bool(5.4)
v = bool("Avi")
v = bool("0")
v = bool("")
print(v)
print(type(v))
# Out:
# False
# <class 'bool'>

# %%
print(4*"5")
# Out:
# 5555

# %%
a= input("Enter a string = ")
print(a)

# %%
x=int(input(" Enter first num = "))
y=int(input(" Enter second num = "))
z=int(input(" Enter third num = "))
print(f"Addition =  {x} + {y} + {z}")
