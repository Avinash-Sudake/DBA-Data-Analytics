# %%
# Python Day - 4

# %%
# .format

v = 9
c = 10
print("The Vlaue in V =",v)
print("The Vlaue in V ={}".format(v))
print("The Vlaue in V ={}".format(c))
print("The Vlaue in V ={} {}".format(c , v))

# %%
# %

g=7
print(" The Value in g = ",g)
print(" The Value in g = %d"%(g))

# %%
# # Conditional Statemet

# # if Statement

# if Condition:
#   True Statement
age=20
if age>18:
  print("You Can Vote")

# %%
# if else
age=int(input("Enter Your Age = "))
if age>18:
  print("You Can Vote")
else:
  print("You Can Not Vote")

# %%
# Program for find the odd even number
num=int(input("Enter Your num = "))
if num %2==0:
  print("even")
else:
  print("odd")

# %%
abc=input("Enter A String :")
if abc == abc[::-1]:
  print("Palindrome")
else:
  print("Not A Palindrome ")

# %%
# Program for find the Gretter number

num1 = int(input("Enter a num 1= "))
num2 = int(input("Enter a num 2= "))
if num1>num2:
  print("Num 1 Gretter")
else:
  print("Num 2 Gretter")

# %%
# Program for vowles

a = (input("Enter a String  "))
if "a"in a or "e"in a or "i"in a or "o"in a or "u" in a:
  print("Ovles")
else:
  print("Not Vowles")

# %%
if 89>60 and 89<80:
  print("Yes")
else:
  print("NO")
